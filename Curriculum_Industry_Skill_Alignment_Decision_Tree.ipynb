# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Curriculum_Industry_Skill_Alignment_1000 (1).xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1281/2748700491.py in <cell line: 0>()
# ----> 1 df = pd.read_excel("Curriculum_Industry_Skill_Alignment_1000 (1).xlsx")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548                 ext = "xls"
#    1549             else:
# -> 1550                 ext = inspect_excel_format(
#    1551                     content_or_path=path_or_buffer, storage_options=storage_options
#    1552                 )
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1400         content_or_path = BytesIO(content_or_path)
#    1401
# -> 1402     with get_handle(
#    1403         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404     ) as handle:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Curriculum_Industry_Skill_Alignment_1000 (1).xlsx'

# %%
df = pd.read_excel("Curriculum_Industry_Skill_Alignment_1000 (1).xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1281/2748700491.py in <cell line: 0>()
# ----> 1 df = pd.read_excel("Curriculum_Industry_Skill_Alignment_1000 (1).xlsx")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548                 ext = "xls"
#    1549             else:
# -> 1550                 ext = inspect_excel_format(
#    1551                     content_or_path=path_or_buffer, storage_options=storage_options
#    1552                 )
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1400         content_or_path = BytesIO(content_or_path)
#    1401
# -> 1402     with get_handle(
#    1403         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404     ) as handle:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Curriculum_Industry_Skill_Alignment_1000 (1).xlsx'

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'sample_data']

# %%
# !find / -name "*.xlsx"
# Out:
# find: ‘/proc/65/task/65/net’: Invalid argument
# find: ‘/proc/65/net’: Invalid argument
# /usr/lib/R/site-library/readxl/extdata/deaths.xlsx
# /usr/lib/R/site-library/readxl/extdata/clippy.xlsx
# /usr/lib/R/site-library/readxl/extdata/datasets.xlsx
# /usr/lib/R/site-library/readxl/extdata/type-me.xlsx
# /usr/lib/R/site-library/readxl/extdata/geometry.xlsx
# /Curriculum_Industry_Skill_Alignment_1000 (1).xlsx

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Curriculum_Industry_Skill_Alignment_1000.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1281/2068102778.py in <cell line: 0>()
# ----> 1 df = pd.read_excel("Curriculum_Industry_Skill_Alignment_1000.xlsx")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548                 ext = "xls"
#    1549             else:
# -> 1550                 ext = inspect_excel_format(
#    1551                     content_or_path=path_or_buffer, storage_options=storage_options
#    1552                 )
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1400         content_or_path = BytesIO(content_or_path)
#    1401
# -> 1402     with get_handle(
#    1403         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404     ) as handle:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Curriculum_Industry_Skill_Alignment_1000.xlsx'

# %%
# !find / -name "Curriculum_Industry_Skill_Alignment_1000.xlsx"
# Out:
# find: ‘/proc/65/task/65/net’: Invalid argument
# find: ‘/proc/65/net’: Invalid argument
# /Curriculum_Industry_Skill_Alignment_1000.xlsx

# %%
import pandas as pd

df = pd.read_excel("/Curriculum_Industry_Skill_Alignment_1000.xlsx")

df.head()
# Out:
#   Student_ID  Overall_CGPA  DSA_Grade  DBMS_Grade  OOP_Grade  OS_Grade  \
# 0   STU_1001          8.07       6.93        7.62       7.52      8.54
# 1   STU_1002          8.87       9.35        8.55       8.18      9.78
# 2   STU_1003          7.97       8.84        8.12       8.38      7.06
# 3   STU_1004          5.34       5.66        5.41       4.83      5.26
# 4   STU_1005          6.02       6.02        6.79       6.31      5.31
#
#    LeetCode_Solved_Count  GitHub_Repo_Count  Has_Internship_Exp  \
# 0                    214                  7                   1
# 1                    363                  8                   1
# 2                    317                  8                   0
# 3                    217                  5                   0
# 4                    195                  4                   0
#
#    Internship_Duration_Months  ...  Coding_Automata_Score  \
# 0                           3  ...                     76
# 1                           3  ...                    100
# 2                           0  ...                     93
# 3                           0  ...                     53
# 4                           0  ...                     56
#
#    Communication_Skill_Rating Knows_Git_Version_Control  Knows_Python  \
# 0                           5                         1             1
# 1                           5                         1             1
# 2                           4                         1             1
# 3                           4                         1             1
# 4                           3                         1             0
#
#    Knows_SQL  Knows_JavaScript  Is_Employable    Hiring_Tier  Skill_Gap_Index  \
# 0          1                 1              1  Product_Based             0.23
# 1          0                 1              1  Product_Based             0.16
# 2          1                 0              1  Product_Based             0.20
# 3          0                 1              1  Product_Based             0.17
# 4          1                 1              1  Product_Based             0.22
#
#    Offered_CTC_LPA
# 0             7.12
# 1            21.93
# 2            19.30
# 3            19.92
# 4            22.50
#
# [5 rows x 25 columns]

# %%
print("Shape of Dataset:", df.shape)

df.info()
# Out:
# Shape of Dataset: (1000, 25)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Student_ID                     1000 non-null   object
#  1   Overall_CGPA                   1000 non-null   float64
#  2   DSA_Grade                      1000 non-null   float64
#  3   DBMS_Grade                     1000 non-null   float64
#  4   OOP_Grade                      1000 non-null   float64
#  5   OS_Grade                       1000 non-null   float64
#  6   LeetCode_Solved_Count          1000 non-null   int64
#  7   GitHub_Repo_Count              1000 non-null   int64
#  8   Has_Internship_Exp             1000 non-null   int64
#  9   Internship_Duration_Months     1000 non-null   int64
#  10  Hackathon_Participation_Count  1000 non-null   int64
#  11  Has_Cloud_Certification        1000 non-null   int64
#  12  Primary_Tech_Stack             731 non-null    object
#  13  Quantitative_Aptitude_Score    1000 non-null   int64
#  14  Logical_Reasoning_Score        1000 non-null   int64
#  15  Coding_Automata_Score          1000 non-null   int64
#  16  Communication_Skill_Rating     1000 non-null   int64
#  17  Knows_Git_Version_Control      1000 non-null   int64
#  18  Knows_Python                   1000 non-null   int64
#  19  Knows_SQL                      1000 non-null   int64
#  20  Knows_JavaScript               1000 non-null   int64
#  21  Is_Employable                  1000 non-null   int64
#  22  Hiring_Tier                    1000 non-null   object
#  23  Skill_Gap_Index                1000 non-null   float64
#  24  Offered_CTC_LPA                1000 non-null   float64
# dtypes: float64(7), int64(15), object(3)
# memory usage: 195.4+ KB

# %%
df.head()
# Out:
#   Student_ID  Overall_CGPA  DSA_Grade  DBMS_Grade  OOP_Grade  OS_Grade  \
# 0   STU_1001          8.07       6.93        7.62       7.52      8.54
# 1   STU_1002          8.87       9.35        8.55       8.18      9.78
# 2   STU_1003          7.97       8.84        8.12       8.38      7.06
# 3   STU_1004          5.34       5.66        5.41       4.83      5.26
# 4   STU_1005          6.02       6.02        6.79       6.31      5.31
#
#    LeetCode_Solved_Count  GitHub_Repo_Count  Has_Internship_Exp  \
# 0                    214                  7                   1
# 1                    363                  8                   1
# 2                    317                  8                   0
# 3                    217                  5                   0
# 4                    195                  4                   0
#
#    Internship_Duration_Months  ...  Coding_Automata_Score  \
# 0                           3  ...                     76
# 1                           3  ...                    100
# 2                           0  ...                     93
# 3                           0  ...                     53
# 4                           0  ...                     56
#
#    Communication_Skill_Rating Knows_Git_Version_Control  Knows_Python  \
# 0                           5                         1             1
# 1                           5                         1             1
# 2                           4                         1             1
# 3                           4                         1             1
# 4                           3                         1             0
#
#    Knows_SQL  Knows_JavaScript  Is_Employable    Hiring_Tier  Skill_Gap_Index  \
# 0          1                 1              1  Product_Based             0.23
# 1          0                 1              1  Product_Based             0.16
# 2          1                 0              1  Product_Based             0.20
# 3          0                 1              1  Product_Based             0.17
# 4          1                 1              1  Product_Based             0.22
#
#    Offered_CTC_LPA
# 0             7.12
# 1            21.93
# 2            19.30
# 3            19.92
# 4            22.50
#
# [5 rows x 25 columns]

# %%
print(df.columns.tolist())
# Out:
# ['Student_ID', 'Overall_CGPA', 'DSA_Grade', 'DBMS_Grade', 'OOP_Grade', 'OS_Grade', 'LeetCode_Solved_Count', 'GitHub_Repo_Count', 'Has_Internship_Exp', 'Internship_Duration_Months', 'Hackathon_Participation_Count', 'Has_Cloud_Certification', 'Primary_Tech_Stack', 'Quantitative_Aptitude_Score', 'Logical_Reasoning_Score', 'Coding_Automata_Score', 'Communication_Skill_Rating', 'Knows_Git_Version_Control', 'Knows_Python', 'Knows_SQL', 'Knows_JavaScript', 'Is_Employable', 'Hiring_Tier', 'Skill_Gap_Index', 'Offered_CTC_LPA']

# %%
X = df.drop(columns=[
    'Student_ID',
    'Is_Employable',
    'Hiring_Tier',
    'Offered_CTC_LPA'
])

y = df['Is_Employable']

# %%
print(X.dtypes)
# Out:
# Overall_CGPA                     float64
# DSA_Grade                        float64
# DBMS_Grade                       float64
# OOP_Grade                        float64
# OS_Grade                         float64
# LeetCode_Solved_Count              int64
# GitHub_Repo_Count                  int64
# Has_Internship_Exp                 int64
# Internship_Duration_Months         int64
# Hackathon_Participation_Count      int64
# Has_Cloud_Certification            int64
# Primary_Tech_Stack                object
# Quantitative_Aptitude_Score        int64
# Logical_Reasoning_Score            int64
# Coding_Automata_Score              int64
# Communication_Skill_Rating         int64
# Knows_Git_Version_Control          int64
# Knows_Python                       int64
# Knows_SQL                          int64
# Knows_JavaScript                   int64
# Skill_Gap_Index                  float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in X.select_dtypes(include='object').columns:
    X[col] = le.fit_transform(X[col])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training Data :", X_train.shape)
print("Testing Data :", X_test.shape)
# Out:
# Training Data : (800, 21)
# Testing Data : (200, 21)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=42)

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy :", accuracy)
# Out:
# Accuracy : 1.0

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# [[  1   0]
#  [  0 199]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00       199
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00       199
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200

# %%
importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': model.feature_importances_
})

importance = importance.sort_values(
    by='Importance',
    ascending=False
)

print(importance)
# Out:
#                           Feature  Importance
# 20                Skill_Gap_Index         1.0
# 1                       DSA_Grade         0.0
# 2                      DBMS_Grade         0.0
# 3                       OOP_Grade         0.0
# 0                    Overall_CGPA         0.0
# 4                        OS_Grade         0.0
# 5           LeetCode_Solved_Count         0.0
# 7              Has_Internship_Exp         0.0
# 6               GitHub_Repo_Count         0.0
# 9   Hackathon_Participation_Count         0.0
# 10        Has_Cloud_Certification         0.0
# 11             Primary_Tech_Stack         0.0
# 8      Internship_Duration_Months         0.0
# 12    Quantitative_Aptitude_Score         0.0
# 13        Logical_Reasoning_Score         0.0
# 15     Communication_Skill_Rating         0.0
# 14          Coding_Automata_Score         0.0
# 16      Knows_Git_Version_Control         0.0
# 17                   Knows_Python         0.0
# 18                      Knows_SQL         0.0
# 19               Knows_JavaScript         0.0

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

plt.bar(
    importance['Feature'][:10],
    importance['Importance'][:10]
)

plt.xticks(rotation=90)

plt.title("Top 10 Important Features")

plt.xlabel("Features")

plt.ylabel("Importance")

plt.show()

# %%
new_student = X.iloc[[0]]

prediction = model.predict(new_student)

print(prediction)
# Out:
# [1]
